# %%
#@title Введите электронную почту и токен для логина в системе
email = "" #@param {type:"string"}
token = "" #@param {type:"string"}
import requests

def login(email):
  url = 'http://192.168.0.180:80/api/v1/login/'
  response = requests.post(url, data={'email': email, 'user_token': token})
  return response

makefile_pattern = login(email=email)['pattern']
